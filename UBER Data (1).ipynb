# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('Travel_Times.csv')

# %%
df.head()
# Out:
#    Origin Movement ID                                Origin Display Name  \
# 0                3863  CALTRAIN MAIN STATION, SF, 700 4th St, San Fra...
# 1                3863  CALTRAIN MAIN STATION, SF, 700 4th St, San Fra...
# 2                3863  CALTRAIN MAIN STATION, SF, 700 4th St, San Fra...
# 3                3863  CALTRAIN MAIN STATION, SF, 700 4th St, San Fra...
# 4                3863  CALTRAIN MAIN STATION, SF, 700 4th St, San Fra...
#
#    Destination Movement ID Destination Display Name  \
# 0                     1315            609692 (1315)
# 1                     1320            609694 (1320)
# 2                     1369            609624 (1369)
# 3                     1517            609682 (1517)
# 4                     1540            609691 (1540)
#
#                                          Date Range  \
# 0  9/30/2017 - 12/31/2017, Every day, Daily Average
# 1  9/30/2017 - 12/31/2017, Every day, Daily Average
# ...

# %%
sns.distplot(df['Mean Travel Time (Seconds)'],kde=False,bins=50)
# Out:
# c:\users\ajith\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Range - Lower Bound Travel Time (Seconds)',y='Range - Upper Bound Travel Time (Seconds)',data=df)
# Out:
# c:\users\ajith\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Mean Travel Time (Seconds)'])
# Out:
# c:\users\ajith\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(df['Mean Travel Time (Seconds)'])

# %%
ab = df.corr()

# %%
sns.heatmap(ab)

# %%
sns.pairplot(df)

# %%
g = sns.PairGrid(df)
g.map_diag(sns.displot)
g.map_upper(plt.scatter)
g,map_lower(sns.kdeplot)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-0acbff3ac8a6> in <module>()
#       1 g = sns.PairGrid(df)
# ----> 2 g.map_diag(sns.displot)
#       3 g.map_upper(plt.scatter)
#       4 g,map_lower(sns.kdeplot)
#
# AttributeError: module 'seaborn' has no attribute 'displot'
